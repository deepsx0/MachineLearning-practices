# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report , confusion_matrix

# %%
from sklearn.linear_model import Perceptron

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
data = pd.DataFrame(iris.data , columns = iris.feature_names)
y = pd.DataFrame(iris.target , columns = ["variety"])

# %%
std_scaler = StandardScaler()

# %%
x_train , x_test ,y_train ,y_test = train_test_split(data , y)

# %%
std_xtrain = std_scaler.fit_transform(x_train)
std_xtest = std_scaler.fit_transform(x_test)

# %%
perceptron = Perceptron(max_iter = 50 , eta0 = 0.15 , tol = 1e-3)
perceptron.fit(std_xtrain , np.ravel(y_train))
# Out:
# Perceptron(eta0=0.15, max_iter=50)

# %%
y_pred = perceptron.predict(std_xtest)

# %%
print(np.ravel(y_test))
# Out:
# [2 1 0 0 2 0 0 1 1 0 1 1 1 2 1 1 1 0 2 2 0 1 2 0 2 0 2 1 2 1 0 0 2 2 0 1 0
#  2]

# %%
print(np.ravel(y_pred))
# Out:
# [2 2 0 0 2 0 0 1 2 0 1 2 2 2 1 1 1 0 2 2 0 2 2 0 2 0 2 1 2 2 0 0 2 2 0 2 0
#  2]

# %%
print(classification_report(y_pred , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.46      1.00      0.63         6
#            2       1.00      0.63      0.77        19
#
#     accuracy                           0.82        38
#    macro avg       0.82      0.88      0.80        38
# weighted avg       0.91      0.82      0.83        38
