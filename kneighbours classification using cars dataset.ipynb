# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
from sklearn.preprocessing import scale

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn import neighbors , preprocessing

# %%
df = pd.read_csv("C:\\Users\\Deependra\\car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.columns = ['carname','year','sp','presprice','kms','fuel','seller','transmission','owner']

# %%
df.head()
# Out:
#    carname  year    sp  presprice    kms    fuel  seller transmission  owner
# 0     ritz  2014  3.35       5.59  27000  Petrol  Dealer       Manual      0
# 1      sx4  2013  4.75       9.54  43000  Diesel  Dealer       Manual      0
# 2     ciaz  2017  7.25       9.85   6900  Petrol  Dealer       Manual      0
# 3  wagon r  2011  2.85       4.15   5200  Petrol  Dealer       Manual      0
# 4    swift  2014  4.60       6.87  42450  Diesel  Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carname       301 non-null    object
#  1   year          301 non-null    int64
#  2   sp            301 non-null    float64
#  3   presprice     301 non-null    float64
#  4   kms           301 non-null    int64
#  5   fuel          301 non-null    object
#  6   seller        301 non-null    object
#  7   transmission  301 non-null    object
#  8   owner         301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
fuel = df.fuel
fuel
# Out:
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
#         ...
# 296    Diesel
# 297    Petrol
# 298    Petrol
# 299    Diesel
# 300    Petrol
# Name: fuel, Length: 301, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
enc_fuel = label.fit_transform(fuel)

# %%
enc_fuel = pd.DataFrame(enc_fuel , columns = ["enc_fuel"])

# %%
enc_fuel.head()
# Out:
#    enc_fuel
# 0         2
# 1         1
# 2         2
# 3         2
# 4         1

# %%
df.drop('fuel' , inplace = True, axis = 1)

# %%
df = pd.concat([df,enc_fuel] , axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carname       301 non-null    object
#  1   year          301 non-null    int64
#  2   sp            301 non-null    float64
#  3   presprice     301 non-null    float64
#  4   kms           301 non-null    int64
#  5   seller        301 non-null    object
#  6   transmission  301 non-null    object
#  7   owner         301 non-null    int64
#  8   enc_fuel      301 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 21.3+ KB

# %%
df.head()
# Out:
#    year    sp  presprice    kms  owner  enc_fuel
# 0  2014  3.35       5.59  27000      0         2
# 1  2013  4.75       9.54  43000      0         1
# 2  2017  7.25       9.85   6900      0         2
# 3  2011  2.85       4.15   5200      0         2
# 4  2014  4.60       6.87  42450      0         1

# %%
x_prime = df[['year','presprice','kms','owner',]]
x_sam = ['year','presprice','kms','owner',]

# %%
x = scale(x_prime)
y = df.enc_fuel

# %%
model = KNeighborsClassifier()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
model.fit(x_train , y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      0.29      0.40        14
#            2       0.86      0.97      0.91        62
#
#     accuracy                           0.84        76
#    macro avg       0.76      0.63      0.65        76
# weighted avg       0.82      0.84      0.82        76
